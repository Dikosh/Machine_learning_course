# %% [markdown]
# # Machine learning
#
# ![!image](../e.jpeg)

# %% [markdown]
# * [First day](#section2)
#     - [Difference between AI, DS, ML and DL](#section_1.1)
#     - [Three common types of ML](#section_1.2)
#     - [General architecture of ML](#section_1.3)
#     - [Linear regression 101](#section_1.4)
#     - [OLS Stats Model (Ordinary Least Square)](#section_1.5)

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# # First Day

# %% [markdown]
# <a id='section_1.1'></a>

# %% [markdown]
# ## Difference between AI, DS, ML and DL
#
# **Artifical intelligence** -  it is a pure math and science, but when it become computational, then it start to solve human problems.
#
# We can divide modern AI into two groups:
#
# * General AI - planning, decision making, identifying objects, recognizing sounds etc.
# * Applied AI - driverless cars etc.
#
# **Machine learning** - algorithmic approach, when computer learns something from data by itself / learn something without explicit knowledge. Machine learning is the form of the AI, just based on more data. There is 3 types of machine learning
#     - Supervised
#     - Unsupervised
#     - Reinforcement learning
#
# **Data Science** - data science is the set of technologies,the  goal is to bring from data some driven data decisions (predictions, recommendations, automatically generating music, content etc), in data science we can include many techniques, algorithms to handle with big data and make decisions from this data.
#
# If machine learning relies more to the math and some science, then data science relies to math and science a little bit less. Altogether data sceince represents for example for: distributed architecture, automated machine learning, data visualization, data engineering, automated data driven decisions, data processing, data acquisition etc and of course machine learning.
#
# **Deep learning** - We can say that DL in the subset of ML, also we can say that ML provides the desired output from a given input, but DL reads the input and applies it to another data. When ML starts to be not sufficient for several tasks like speech to text, text to speech etc, there is discovered DL.

# %% [markdown]
# <a id='section_1.2'></a>

# %% [markdown]
# ##  Lets refresh our memory about common 3 types of machine learning
#
# **Supervised learning** - we should just stick in our minds that supervised learning, is the algorithmic method, when we have target, i.e. independent variable, the variable which we must to predict, find. (regression and classification)
#
# **Unsupervised learning** -in contrast uses unlabeled data, then algorithm tries to make sense by extracting features, finding some anomalies etc.
#     - Clustering, Anomaly Detection, Assosiation, Autoencoders
#
# **Reinforcement learning** - is less supervised learning, and depends on the learning agent, algorithm tries to achieve best solution.

# %% [markdown]
# <a id='section_1.3'></a>

# %% [markdown]
# ## General architecture of machine learning
#
#
# Start > Business understanding > Modeling / Data acquisition and understanding > Deployment
#
# In modeiling we can include:
# - feature egnineering
# - model training
# - model evaluation
#
# In data acquisition and understanding we can include:
# - data source
# - pipelines
# - environment
# - cleaning, wrangling, exploration
#
# in **business understanding** the general architecture of ml is to understand given use case, and also it is good to know more about domain problem for which we are going to do ml algorithm
#
# **data acquisition and understanding**  is to know about data gathering from different source, understanding the data, cleaning, handling with outliers and missed data etc.

# %% [markdown]
# <a id='section_1.4'></a>

# %% [markdown]
# ## Linear regression
# Lm tends to establish a relationshiop between dependent and independent variable by fitting the best fit of the straight line. There are two types of linear regression- **Simple and Multiple**.
# Y = wx+b
#
# ### Simple Linear Regression and Multiple Linear Regression
#
# Simple linear regression is useful for finding relationship between two continuous variables. One is predictor or independent variable and other is response or dependent variable. It looks for statistical relationship but not deterministic relationship. Relationship between two variables is said to be **deterministic** if one variable can be accurately expressed by the other. For example, using temperature in degree Celsius it is possible to accurately predict Fahrenheit. **Statistical** relationship is not accurate in determining relationship between two variables. For example, relationship between height and weight. We use **Multiple linear regression** when have multiple dependent variables and one independent variable.
#
# `The core idea is to obtain a line that best fits the data. The best fit line is the one for which total prediction error (all data points) are as small as possible. Error is the distance between the point to the regression line.`
#
# Before moving on to the algorithm, let’s have a look at two important concepts you must know to better understand linear regression.
#
# is Cost function and Gradient descent
#
# **Cost function**
# The cost function helps us to figure out the best possible values  which would provide the best fit line for the data points. Since we want the best values of weights, we convert this search problem into a minimization problem where we would like to minimize the error between the predicted value and the actual value. Usually we use MSE as cost function
#
# **Gradient descent**
# The next important concept needed to understand linear regression is gradient descent. Gradient descent is a method of updating weights to reduce the cost function(MSE). The idea is that we start with some values fweights and then we change these values iteratively to reduce the cost. Gradient descent helps us on how to change the values. We must also now some traps, for example convex and non-convex distributions. Sometimes the cost function can be a non-convex function where you could settle at a local minima but for linear regression, it is always a convex function.
#
# ### Conditions to use linear regression
#
# And also there is some tips and techniques about where and how you can use linear regression, but now lets just glimpse at the main conditions where your linear model will show you good results)
#
# 1. Correlation between independent variable and dependent variables
# 2. Exclude of heteredoscaticity (sorry if i write hetero******** with errors)
# 3. Existence of homodescadisity
# 4. Absence of multicollinearity
# 5. etc.
#
# for the beginning these 4 rules is enough for us.
#
# ### Let's go on! and talk about Metrics for model evaluation
#
# #### R-squared
#
# R-squared is a stastical measure of how close the data are to the fitted regression line. It is also known as **coefficient of determination**, or the coefficient of multiple determination for multiple regression.
#
# The definition of R-squared is the percentage of the respone variable variation that is explained by a linear model.
#
# R-squared = Explained Variation / Total Variation
#
# R-squared always between 0 and 1, where 0 indicates that the model explains none of the variability of the response data around its mean and 1 indicates that the model explains all the variability of the response data around its mean.
#
# the problem of R-squared is how many junk independent variables or important independent variable or impactful independent variable you add to your model, the R-squared valie will always increase. It will never decrease with the addition of a newly independent variable, whether it could be an impactful, non-impactful, or bad variable. so we need another way to measure equivalent R-square, which is penalizes our model with any junk independent variable.
#
# So, we calculate **Adjusted R-square** with a better adjustment in the formula of generic R-square
#
#
# Lets try to understand formula
#
# for better understanding, lets look at the example:
# here by we have **weights of mouses and their number of id**
#
# ![](pics/1.png)
#
#
# **First** thing we should do is to calculate mean of their weights, and plot it as a line in our graphic. Then we can calculate  variation of the  data around this mean as the sum of squared differences of the weight of each mouse) we call it **Regression sum of squares (SSR)**
# This gives information about how far estimated regression line is from the horizontal ‘no relationship’ line (average of actual output).
#
# ![](pics/2.png)
#
# now what if instead of ordering these mice  by their ID we ordered them by their size?
# ![](pics/3.png)
#
# now to fit the weight for another mice we just should plot a line, now we can predict the weight with our line, you tell me about bis sized mouse, good, i will look at my line and will predict the weight.
#
# **now here is a question,**
# ![](pics/4.png)
#
# by eye, its look like that blue line fits better than mean, now **how do we quantify that difference**? Yes you a right, we use **R-squared**
#
#
# `R^2 = (Var(Mean)-Var(Line))/Var(mean)`
#
#
#
# ### references:
# 1. [Linear Regression — Detailed View](https://towardsdatascience.com/linear-regression-detailed-view-ea73175f6e86)
# 2. [StatQuest: R-squared explained](https://www.youtube.com/watch?v=2AQKmw14mHM)

# %% [markdown]
# <a id='section_1.5'></a>

# %% [markdown]
# ##  OLS Stats Model

# %%
 ! jupyter nbconvert --to html -template basic ML1.ipynb
# Out:
# This application is used to convert notebook files (*.ipynb) to various other
# formats.
#
# WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# -------
#
# Arguments that take values are actually convenience aliases to full
# Configurables, whose aliases are listed on the help line. For more information
# on full configurables, see '--help-all'.
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
# --generate-config
#     generate default config file
# -y
#     Answer yes to any questions instead of prompting.
# --execute
#     Execute the notebook prior to export.
# --allow-errors
#     Continue notebook execution even if one of the cells throws an error and include the error message in the cell output (the default behaviour is to abort conversion). This flag is only relevant if '--execute' was specified, too.
# --stdin
#     read a single notebook file from stdin. Write the resulting notebook with default basename 'notebook.*'
# ...
